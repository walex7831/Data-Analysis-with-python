# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/E-StudyVault-Copy.csv')

# %%
df.head()
# Out:
#   What is your age range? What is your gender? What is your academic level?  \
# 0                 26 - 35               Female                Undergraduate
# 1                 18 - 25               Female                Undergraduate
# 2                 26 - 35                 Male                   Researcher
# 3                 18 - 25               Female                Undergraduate
# 4                 18 - 25                 Male                Undergraduate
#
#        Field of study? How often do you use digital study materials?  \
# 0  Business Management                                         Daily
# 1      Health Sciences                                         Daily
# 2      Health Sciences                                         Daily
# 3    Arts & Humanities                                         Daily
# 4          Engineering                                         Daily
#
#   How do you currently store your academic materials? (Select all that apply)  \
# ...

# %%
df.shape
# Out:
# (139, 32)

# %%
df.columns
# Out:
# Index(['What is your age range?', 'What is your gender?',
#        'What is your academic level?', 'Field of study?',
#        'How often do you use digital study materials?',
#        'How do you currently store your academic materials? (Select all that apply)',
#        'What challenges do you face in managing your study materials? (Select all that apply)',
#        'Have you ever lost important study materials due to device failure or accidental deletion?',
#        'If yes, how did it affect your academic work?',
#        'How do you organize your study materials?',
#        'How secure do you feel your current method of storing academic materials is?',
#        'Would you find a personalized E-study Vault useful for managing your academic materials?',
#        'What features would you like to see in the E-study Vault? (Select all that apply)',
#        'How important is offline access to you?',
#        'How important is data security and privacy in a study vault system?',
# ...

# %%
df.describe()
# Out:
#        What is your age range? What is your gender?  \
# count                      139                  139
# unique                       4                    2
# top                    18 - 25               Female
# freq                       112                   94
#
#        What is your academic level? Field of study?  \
# count                           139             139
# unique                            7              25
# top                   Undergraduate        Sciences
# freq                            105              46
#
#        How often do you use digital study materials?  \
# count                                            139
# unique                                             4
# top                                            Daily
# freq                                              74
#
#        How do you currently store your academic materials? (Select all that apply)  \
# count                                                 139
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139 entries, 0 to 138
# Data columns (total 32 columns):
#  #   Column                                                                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                                                                    --------------  -----
#  0   What is your age range?                                                                                                                   139 non-null    object
#  1   What is your gender?                                                                                                                      139 non-null    object
#  2   What is your academic level?                                                                                                              139 non-null    object
# ...

# %%
df.isna().head() #checking missing values
# Out:
#    What is your age range?  What is your gender?  \
# 0                    False                 False
# 1                    False                 False
# 2                    False                 False
# 3                    False                 False
# 4                    False                 False
#
#    What is your academic level?  Field of study?  \
# 0                         False            False
# 1                         False            False
# 2                         False            False
# 3                         False            False
# 4                         False            False
#
#    How often do you use digital study materials?  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
# ...

# %%
df.nunique() #checking duplicate
# Out:
# What is your age range?                                                                                                                      4
# What is your gender?                                                                                                                         2
# What is your academic level?                                                                                                                 7
# Field of study?                                                                                                                             25
# How often do you use digital study materials?                                                                                                4
# How do you currently store your academic materials? (Select all that apply)                                                                 18
# ...

# %%
df.isna().sum() #numbers of missing column in the columns
# Out:
# What is your age range?                                                                                                                      0
# What is your gender?                                                                                                                         0
# What is your academic level?                                                                                                                 0
# Field of study?                                                                                                                              0
# How often do you use digital study materials?                                                                                                0
# How do you currently store your academic materials? (Select all that apply)                                                                  0
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
#removing column from data
df = df.drop(['Do you have any additional suggestions or comments regarding the development of the E-study Vault?'], axis= 1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139 entries, 0 to 138
# Data columns (total 31 columns):
#  #   Column                                                                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                                                                    --------------  -----
#  0   What is your age range?                                                                                                                   139 non-null    object
#  1   What is your gender?                                                                                                                      139 non-null    object
#  2   What is your academic level?                                                                                                              139 non-null    object
# ...

# %%
df.head()
# Out:
#   What is your age range? What is your gender? What is your academic level?  \
# 0                 26 - 35               Female                Undergraduate
# 1                 18 - 25               Female                Undergraduate
# 2                 26 - 35                 Male                   Researcher
# 3                 18 - 25               Female                Undergraduate
# 4                 18 - 25                 Male                Undergraduate
#
#        Field of study? How often do you use digital study materials?  \
# 0  Business Management                                         Daily
# 1      Health Sciences                                         Daily
# 2      Health Sciences                                         Daily
# 3    Arts & Humanities                                         Daily
# 4          Engineering                                         Daily
#
#   How do you currently store your academic materials? (Select all that apply)  \
# ...

# %%
df.describe().T
# Out:
#                                                    count unique  \
# What is your age range?                              139      4
# What is your gender?                                 139      2
# What is your academic level?                         139      7
# Field of study?                                      139     25
# How often do you use digital study materials?        139      4
# How do you currently store your academic materi...   139     18
# What challenges do you face in managing your st...   139     22
# Have you ever lost important study materials du...   139      2
# If yes, how did it affect your academic work?        114      4
# How do you organize your study materials?            139      7
# How secure do you feel your current method of s...   139      5
# Would you find a personalized E-study Vault use...   139      3
# What features would you like to see in the E-st...   139     43
# How important is offline access to you?              139      4
# ...

# %%
df['What is your gender?'].value_counts().plot(kind='pie', title= 'What is your gender?', legend=True, autopct='%1.1f%%')
# Out:
# <Axes: title={'center': 'What is your gender?'}, ylabel='count'>

# %%
df['What is your age range?'].value_counts().plot(kind='pie', title='What is your age range?', legend=True, autopct='%1.1f%%')
# Out:
# <Axes: title={'center': 'What is your age range?'}, ylabel='count'>

# %%
df['How often do you use digital study materials?'].value_counts().plot(kind='pie', title='How often do you use digital study materials?', legend=True, autopct='%1.1f%%')
#plt.title('How often do you use digital study materials?')
# Out:
# <Axes: title={'center': 'How often do you use digital study materials?'}, ylabel='count'>

# %%
df['Have you ever lost important study materials due to device failure or accidental deletion?'].value_counts().plot(kind='pie', title='Have you ever lost important study materials due to device failure or accidental deletion?', legend=True, autopct='%1.1f%%')
# Out:
# <Axes: title={'center': 'Have you ever lost important study materials due to device failure or accidental deletion?'}, ylabel='count'>

# %%
df['Would you like the system to provide reminders for pending assignments or research deadlines?'].value_counts().plot(kind='pie', title='Would you like the system to provide reminders for pending assignments or research deadlines?', legend=True, autopct='%1.1f%%')
# Out:
# <Axes: title={'center': 'Would you like the system to provide reminders for pending assignments or research deadlines?'}, ylabel='count'>

# %%
df['Would you like the E-study Vault to have an AI-powered recommendation system to suggest relevant study materials?'].value_counts().plot(kind='pie', title='Would you like the E-study Vault to have an AI-powered recommendation system to suggest relevant study materials?', legend=True, autopct='%1.1f%%')
# Out:
# <Axes: title={'center': 'Would you like the E-study Vault to have an AI-powered recommendation system to suggest relevant study materials?'}, ylabel='count'>

# %%
df['Would you be willing to participate in testing the E-study Vault prototype once developed?'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
# %matplotlib inline

# %%
df['What are the biggest frustrations you have with existing digital storage platforms?'].value_counts().plot(kind='pie', title='What are the biggest frustrations you have with existing digital storage platforms?', color='green', legend=True, autopct='%1.1f%%')
# Out:
# <Axes: title={'center': 'What are the biggest frustrations you have with existing digital storage platforms?'}, ylabel='count'>

# %%
df['Field of study?'].value_counts().plot(kind='bar', legend=True)
# Out:
# <Axes: xlabel='Field of study?'>

# %%
said_no = df[df['Have you ever lost important study materials due to device failure or accidental deletion?'] == 'No']
said_no.head()
# Out:
#    What is your age range? What is your gender? What is your academic level?  \
# 1                  18 - 25               Female                Undergraduate
# 2                  26 - 35                 Male                   Researcher
# 4                  18 - 25                 Male                Undergraduate
# 5                  18 - 25               Female                Undergraduate
# 11                 18 - 25                 Male                Undergraduate
#
#     Field of study? How often do you use digital study materials?  \
# 1   Health Sciences                                         Daily
# 2   Health Sciences                                         Daily
# 4       Engineering                                         Daily
# 5       Accounting                                   Occasionally
# 11  Social Sciences                                        Weekly
#
#    How do you currently store your academic materials? (Select all that apply)  \
# ...

# %%
said_no.shape
# Out:
# (34, 31)

# %%
said_yes = df[df['Have you ever lost important study materials due to device failure or accidental deletion?'] == 'Yes']
said_yes.head()
# Out:
#   What is your age range? What is your gender? What is your academic level?  \
# 0                 26 - 35               Female                Undergraduate
# 3                 18 - 25               Female                Undergraduate
# 6                 26 - 35               Female                     Lecturer
# 7                 18 - 25               Female                Undergraduate
# 8                 18 - 25               Female                Undergraduate
#
#                     Field of study?  \
# 0               Business Management
# 3                 Arts & Humanities
# 6  Library and information science
# 7                 Arts & Humanities
# 8                       Engineering
#
#   How often do you use digital study materials?  \
# 0                                         Daily
# 3                                         Daily
# 6                                         Daily
# 7                                         Daily
# ...

# %%
print(len('What is your age range?'))
print(len('What is your academic level?'))
# Out:
# 23
# 28

# %%
filtered_1 = df[(df['Have you ever lost important study materials due to device failure or accidental deletion?'] == 'Yes') & (df['What is your academic level?'] == 'Undergraduate')]
filtered_2 = df[(df['Would you prefer to listen to the audio version of the PDFs'] == 'Yes') & (df['What is your gender?'] == 'Female')]

# %%
print(filtered_1['Have you ever lost important study materials due to device failure or accidental deletion?'].value_counts())
print(filtered_1['What is your academic level?'].value_counts())
# Out:
# Have you ever lost important study materials due to device failure or accidental deletion?
# Yes    77
# Name: count, dtype: int64
# What is your academic level?
# Undergraduate    77
# Name: count, dtype: int64

# %%
print(filtered_2['Would you prefer to listen to the audio version of the PDFs'].value_counts())
print(filtered_2['What is your gender?'].value_counts())
# Out:
# Would you prefer to listen to the audio version of the PDFs
# Yes    69
# Name: count, dtype: int64
# What is your gender?
# Female    69
# Name: count, dtype: int64

# %%
df['How do you currently store your academic materials? (Select all that apply)'].head()
# Out:
# 0    Personal Computer/Laptop storage;Cloud storage...
# 1    Cloud storage (Google Drive, OneDrive, Dropbox...
# 2    Cloud storage (Google Drive, OneDrive, Dropbox...
# 3                     Personal Computer/Laptop storage
# 4                     Personal Computer/Laptop storage
# Name: How do you currently store your academic materials? (Select all that apply), dtype: object

# %%
python_bool = df['How do you currently store your academic materials? (Select all that apply)'].str.contains('Personal Computer/Laptop storage')
python_bool.value_counts()
# Out:
# How do you currently store your academic materials? (Select all that apply)
# True     75
# False    64
# Name: count, dtype: int64

# %%
academic_materials = df['How do you currently store your academic materials? (Select all that apply)'].str.split(';', expand=True)
academic_materials.head()
# Out:
#                                                    0  \
# 0                   Personal Computer/Laptop storage
# 1  Cloud storage (Google Drive, OneDrive, Dropbox...
# 2  Cloud storage (Google Drive, OneDrive, Dropbox...
# 3                   Personal Computer/Laptop storage
# 4                   Personal Computer/Laptop storage
#
#                                                    1  \
# 0  Cloud storage (Google Drive, OneDrive, Dropbox...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                                  2                      3
# 0  Physical storage (Printed materials, notebooks)  Mobile device storage
# 1                                             None                   None
# 2                                             None                   None
# ...

# %%
academic_materials.stack()
# Out:
# 0    0                     Personal Computer/Laptop storage
#      1    Cloud storage (Google Drive, OneDrive, Dropbox...
#      2      Physical storage (Printed materials, notebooks)
#      3                                Mobile device storage
# 1    0    Cloud storage (Google Drive, OneDrive, Dropbox...
# 2    0    Cloud storage (Google Drive, OneDrive, Dropbox...
# 3    0                     Personal Computer/Laptop storage
# 4    0                     Personal Computer/Laptop storage
# 5    0                     Personal Computer/Laptop storage
# 6    0    Cloud storage (Google Drive, OneDrive, Dropbox...
# 7    0      Physical storage (Printed materials, notebooks)
#      1                                Mobile device storage
# 8    0                     Personal Computer/Laptop storage
#      1    Cloud storage (Google Drive, OneDrive, Dropbox...
#      2      Physical storage (Printed materials, notebooks)
#      3                                Mobile device storage
# ...

# %%
academic_materials.stack().value_counts()
# Out:
# Mobile device storage                                    96
# Personal Computer/Laptop storage                         75
# Cloud storage (Google Drive, OneDrive, Dropbox, etc.)    71
# Physical storage (Printed materials, notebooks)          68
# University repository or e-library                        4
# Name: count, dtype: int64

# %%
academic_materials.stack().value_counts().plot(kind='pie', title='Academic Materials', legend=True, autopct='%1.1f%%')
# Out:
# <Axes: title={'center': 'Academic Materials'}, ylabel='count'>
